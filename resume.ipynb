# %% [markdown]
# <img src="images/profile.jpg" alt="Jerry Han" style="width:150px; border-radius:50%; float:right; margin-left:20px; margin-bottom:10px;">
#
# # Jerry Han
#
# greetings from a bygone age!
#
# i am jerry and i like to explore inflection points!
#
# cofounder of Gradient
#
# junior @ Princeton, math major
#
# born and raised in Singapore

# %% [markdown]
# ## what i've worked on!
#
# **Co-Founder, [Gradient](https://gradient.build) @ Princeton**
# Gradient is the force that pushes Princeton to the frontier of new ideas.
#
# **Co-President, Princeton Entrepreneurship Club**
# Largest campus organization at Princeton.
#
# **Student Researcher, [Google DeepMind](https://deepmind.google/)**
# Undergraduate researcher at Google DeepMind Princeton under [Prof Elad Hazan](https://www.cs.princeton.edu/~ehazan/). Spectral transformers and preconditioning for time series forecasting.
#
# **Corporal (First Class), Singapore Army**
# Awarded Soldier of the Year
#
# **Quantitative Trader, [Jane Street](https://www.janestreet.com/)**
# Maximizing EV!
#
# **Machine Learning Engineer, Hillspire**
# Worked on applications of video generation models with Eric Schmidt and Sebastian Thrun.
#
# **Intern, [GIC](https://www.gic.com.sg/)**
# Singapore's sovereign wealth fund

# %% [markdown]
# ## Projects
#
# **SearchDestroy**
# Algorithm to sweep an area with multiple drones in the most time efficient way; efficient parametrization of search area and ensuring robustness of algorithm under adversarial interference. Robust multi-drone search algorithm: DARP + heuristics to handle drone loss and online path re-computation. Physics simulation and visualization using AirSim; awarded rank 2nd at AGI House Hackathon (Summer 2024).
#
# **Moco** — [Devpost](https://devpost.com/software/moco)
# Awarded Best Overall Hack at HackPrinceton (Fall 2023).
#
# **ANTIDOTE** — [GitHub](https://github.com/jerryhan60/TDA_SNNS) | [Paper](data/TDA_for_trojan_NNs.pdf)
# Artificial Neural Network Trojan Detection Using Topological Data Analysis Estimators.
#
# **Algorithmic Trading of Cryptocurrency Futures**
# Traded 12 cryptocurrency derivatives on FTX with a monthly volume >$1 million and monthly return of 11%.

# %% [markdown]
# ## Other fun facts!
# - I used to be very involved with [Physics Olympiads](https://ipho-unofficial.org/timeline/2020/)!
# - I love competitive programming! Along with Daniel Yang & Jishnu Roychoudhury, we were 2025 ICPC Greater NY regional champions

# %% [markdown]
# Built with Love :3 by claude code
